# %%
# !pip install yfinance
import yfinance as yf  #downloads the daily stock index prices
import pandas as pd
import os

# %%
if os.path.exists("sp500.csv"):
    sp500 = pd.read_csv("sp500.csv", index_col=0)
else:
    sp500 = yf.Ticker("^GSPC")
    sp500 = sp500.history(period="max")
    sp500.to_csv("sp500.csv")

# %%
sp500.index = pd.to_datetime(sp500.index)
# Out:
# C:\Users\Meher Ahmad\AppData\Local\Temp\ipykernel_15056\318495744.py:1: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   sp500.index = pd.to_datetime(sp500.index)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-08-26 00:00:00-04:00  5639.660156  5651.620117  5602.339844  5616.839844
# 2024-08-27 00:00:00-04:00  5602.890137  5631.180176  5593.479980  5625.799805
# 2024-08-28 00:00:00-04:00  5624.509766  5627.029785  5560.950195  5592.180176
# 2024-08-29 00:00:00-04:00  5607.299805  5646.950195  5583.709961  5591.959961
# 2024-08-30 00:00:00-04:00  5612.740234  5651.370117  5581.790039  5648.399902
#
# ...

# %%
sp500 = yf.Ticker("^GSPC")  #ticker class downloads price history for a single cell

# %%
sp500 = sp500.history(period = "max")  #query all the prices from when the data was created

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-08-26 00:00:00-04:00  5639.660156  5651.620117  5602.339844  5616.839844
# 2024-08-27 00:00:00-04:00  5602.890137  5631.180176  5593.479980  5625.799805
# 2024-08-28 00:00:00-04:00  5624.509766  5627.029785  5560.950195  5592.180176
# 2024-08-29 00:00:00-04:00  5607.299805  5646.950195  5583.709961  5591.959961
# 2024-08-30 00:00:00-04:00  5612.740234  5651.370117  5581.790039  5648.399902
#
# ...

# %%
sp500.index
# Out:
# DatetimeIndex(['1927-12-30 00:00:00-05:00', '1928-01-03 00:00:00-05:00',
#                '1928-01-04 00:00:00-05:00', '1928-01-05 00:00:00-05:00',
#                '1928-01-06 00:00:00-05:00', '1928-01-09 00:00:00-05:00',
#                '1928-01-10 00:00:00-05:00', '1928-01-11 00:00:00-05:00',
#                '1928-01-12 00:00:00-05:00', '1928-01-13 00:00:00-05:00',
#                ...
#                '2024-08-19 00:00:00-04:00', '2024-08-20 00:00:00-04:00',
#                '2024-08-21 00:00:00-04:00', '2024-08-22 00:00:00-04:00',
#                '2024-08-23 00:00:00-04:00', '2024-08-26 00:00:00-04:00',
#                '2024-08-27 00:00:00-04:00', '2024-08-28 00:00:00-04:00',
#                '2024-08-29 00:00:00-04:00', '2024-08-30 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=24283, freq=None)

# %%
sp500.plot.line(y= "Close", use_index=True)  #plots a line graph with the closing stock price on y-axis and index on x-axis
# Out:
# <Axes: xlabel='Date'>

# %%
del sp500["Dividends"]
del sp500["Stock Splits"]

# %%
sp500["Tomorrow"] = sp500["Close"].shift(-1)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-08-26 00:00:00-04:00  5639.660156  5651.620117  5602.339844  5616.839844
# 2024-08-27 00:00:00-04:00  5602.890137  5631.180176  5593.479980  5625.799805
# 2024-08-28 00:00:00-04:00  5624.509766  5627.029785  5560.950195  5592.180176
# 2024-08-29 00:00:00-04:00  5607.299805  5646.950195  5583.709961  5591.959961
# 2024-08-30 00:00:00-04:00  5612.740234  5651.370117  5581.790039  5648.399902
#
# ...

# %%
sp500["Target"] = (sp500["Tomorrow"] > sp500["Close"]).astype(int)  #if tomorrow's closing stock is greater than today's closing it will return 1 else 0

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-08-26 00:00:00-04:00  5639.660156  5651.620117  5602.339844  5616.839844
# 2024-08-27 00:00:00-04:00  5602.890137  5631.180176  5593.479980  5625.799805
# 2024-08-28 00:00:00-04:00  5624.509766  5627.029785  5560.950195  5592.180176
# 2024-08-29 00:00:00-04:00  5607.299805  5646.950195  5583.709961  5591.959961
# 2024-08-30 00:00:00-04:00  5612.740234  5651.370117  5581.790039  5648.399902
#
# ...

# %%
sp500 = sp500.loc["1990-01-01":].copy()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1990-01-02 00:00:00-05:00   353.399994   359.690002   351.980011   359.690002
# 1990-01-03 00:00:00-05:00   359.690002   360.589996   357.890015   358.760010
# 1990-01-04 00:00:00-05:00   358.760010   358.760010   352.890015   355.670013
# 1990-01-05 00:00:00-05:00   355.670013   355.670013   351.350006   352.200012
# 1990-01-08 00:00:00-05:00   352.200012   354.239990   350.540009   353.790009
# ...                                ...          ...          ...          ...
# 2024-08-26 00:00:00-04:00  5639.660156  5651.620117  5602.339844  5616.839844
# 2024-08-27 00:00:00-04:00  5602.890137  5631.180176  5593.479980  5625.799805
# 2024-08-28 00:00:00-04:00  5624.509766  5627.029785  5560.950195  5592.180176
# 2024-08-29 00:00:00-04:00  5607.299805  5646.950195  5583.709961  5591.959961
# 2024-08-30 00:00:00-04:00  5612.740234  5651.370117  5581.790039  5648.399902
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)

train = sp500.iloc[:-100]
test = sp500.iloc[-100:]

predictors = ["Close", "Volume", "Open", "High", "Low"]
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])

# %%
preds = pd.Series(preds, index=test.index)

# %%
precision_score(test["Target"], preds)
# Out:
# 0.5882352941176471

# %%
combined = pd.concat([test["Target"], preds], axis=1)

# %%
combined.plot()

# %%
def predict(train, test, predictors, model):  #create a prediction function for back testing
    model.fit(train[predictors], train["Target"])
    preds = model.predict(test[predictors])  #generating our predictions
    preds = pd.Series(preds, index=test.index, name="Predictions")  #combining the model into a series
    combined = pd.concat([test["Target"], preds], axis=1)  #concat our actual values with our predicted values
    return combined

# %%
def backtest(data, model, predictors, start=2500, step=250):  #the start value is the last 10 years data to train the model
    all_predictions = []  #create a list of dataframes where each dataframe is a prediction for a single year

    for i in range(start, data.shape[0], step):  #the for loop iterates through the data year by year and make predictions except the first 10 or so
        train = data.iloc[0:i].copy()  #all the years prior to the current year
        test = data.iloc[i:(i+step)].copy()  #the current year
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    
    return pd.concat(all_predictions)

# %%
predictions = backtest(sp500, model, predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0    3637
# 1    2596
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5288906009244992

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.535537
# 0    0.464463
# Name: count, dtype: float64

# %%
horizons = [2,5,60,250,1000]
new_predictors = []

for horizon in horizons:
    rolling_averages = sp500.rolling(horizon).mean()
    
    ratio_column = f"Close_Ratio_{horizon}"
    sp500[ratio_column] = sp500["Close"] / rolling_averages["Close"]
    
    trend_column = f"Trend_{horizon}"
    sp500[trend_column] = sp500.shift(1).rolling(horizon).sum()["Target"]
    
    new_predictors+= [ratio_column, trend_column]

# %%
sp500 = sp500.dropna(subset=sp500.columns[sp500.columns != "Tomorrow"])

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1993-12-14 00:00:00-05:00   465.730011   466.119995   462.459991   463.059998
# 1993-12-15 00:00:00-05:00   463.059998   463.690002   461.839996   461.839996
# 1993-12-16 00:00:00-05:00   461.859985   463.980011   461.859985   463.339996
# 1993-12-17 00:00:00-05:00   463.339996   466.380005   463.339996   466.380005
# 1993-12-20 00:00:00-05:00   466.380005   466.899994   465.529999   465.850006
# ...                                ...          ...          ...          ...
# 2024-08-26 00:00:00-04:00  5639.660156  5651.620117  5602.339844  5616.839844
# 2024-08-27 00:00:00-04:00  5602.890137  5631.180176  5593.479980  5625.799805
# 2024-08-28 00:00:00-04:00  5624.509766  5627.029785  5560.950195  5592.180176
# 2024-08-29 00:00:00-04:00  5607.299805  5646.950195  5583.709961  5591.959961
# 2024-08-30 00:00:00-04:00  5612.740234  5651.370117  5581.790039  5648.399902
#
# ...

# %%
model = RandomForestClassifier(n_estimators=200, min_samples_split=50, random_state=1)

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict_proba(test[predictors])[:,1]
    preds[preds >=.6] = 1
    preds[preds <.6] = 0
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
predictions = backtest(sp500, model, new_predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0.0    4390
# 1.0     843
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5729537366548043

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.545194
# 0    0.454806
# Name: count, dtype: float64

# %%
predictions
# Out:
#                            Target  Predictions
# Date
# 2003-11-14 00:00:00-05:00       0          0.0
# 2003-11-17 00:00:00-05:00       0          1.0
# 2003-11-18 00:00:00-05:00       1          1.0
# 2003-11-19 00:00:00-05:00       0          0.0
# 2003-11-20 00:00:00-05:00       1          1.0
# ...                           ...          ...
# 2024-08-26 00:00:00-04:00       1          0.0
# 2024-08-27 00:00:00-04:00       0          1.0
# 2024-08-28 00:00:00-04:00       0          0.0
# 2024-08-29 00:00:00-04:00       1          0.0
# 2024-08-30 00:00:00-04:00       0          1.0
#
# [5233 rows x 2 columns]
